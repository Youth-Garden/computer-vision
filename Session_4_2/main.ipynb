# %% [markdown]
# # Nhận diện khuôn mặt với FaceNet
# Notebook này trình bày hệ thống nhận diện khuôn mặt thời gian thực sử dụng mô hình FaceNet. Hệ thống sử dụng webcam để quay video, phát hiện khuôn mặt và so sánh với hình ảnh đã biết để xác định mức độ tương đồng.

# %%
import cv2
import numpy as np
from mtcnn import MTCNN
from keras_facenet import FaceNet
from scipy.spatial.distance import cosine

# %% [markdown]
# ## Nhập các thư viện cần thiết
# Các thư viện sau được nhập:
# - `cv2`: Xử lý hình ảnh và video.
# - `numpy`: Các phép toán số học.
# - `MTCNN`: Phát hiện khuôn mặt.
# - `FaceNet`: Tạo embedding cho khuôn mặt.
# - `cosine` từ `scipy.spatial.distance`: Tính toán độ tương đồng giữa các embedding.

# %%
detector = MTCNN()
embedder = FaceNet()

# Kiểm tra xem webcam có hoạt động không
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Không thể mở webcam. Vui lòng kiểm tra kết nối hoặc quyền truy cập.")
    cap.release()
    exit()
# Out:
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.

# %% [markdown]
# ## Khởi tạo bộ phát hiện khuôn mặt và tạo embedding
# - `MTCNN` được sử dụng để phát hiện khuôn mặt trong hình ảnh.
# - `FaceNet` được sử dụng để tạo embedding cho các khuôn mặt được phát hiện.
#
# Ngoài ra, webcam được khởi tạo để quay video thời gian thực.

# %%
def get_embedding(face_img):
    face_img = cv2.resize(face_img, (160, 160))
    face_img = face_img.astype('float32')
    face_img = np.expand_dims(face_img, axis=0)
    embedding = embedder.embeddings(face_img)
    return embedding[0]

# %% [markdown]
# ## Định nghĩa hàm tạo embedding
# Hàm `get_embedding` xử lý trước hình ảnh khuôn mặt và tạo embedding của nó bằng mô hình `FaceNet`. Embedding này là biểu diễn số của khuôn mặt, có thể được sử dụng để so sánh độ tương đồng.

# %%
known_img = cv2.imread("anh-the.png")
known_img = cv2.cvtColor(known_img, cv2.COLOR_BGR2RGB)

faces = detector.detect_faces(known_img)
x, y, w, h = faces[0]['box']
known_face = known_img[y:y+h, x:x+w]

known_embedding = get_embedding(known_face)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       5 x, y, w, h = faces[0]['box']
#       6 known_face = known_img[y:y+h, x:x+w]
# ----> 8 known_embedding = get_embedding(known_face)
#
# Cell In[13], line 5, in get_embedding(face_img)
#       3 face_img = face_img.astype('float32')
#       4 face_img = np.expand_dims(face_img, axis=0)
# ----> 5 embedding = embedder.embeddings(face_img)
#       6 return embedding[0]
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras_facenet\__init__.py:113, in FaceNet.embeddings(self, images)
#     111 images = [cv2.resize(image, (s, s)) for image in images]
#     112 X = np.float32([self._normalize(image) for image in images])
# --> 113 embeddings = self.model.predict(X)
#     114 return embeddings
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:588, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     586 callbacks.on_predict_batch_begin(begin_step)
#     587 data = get_data(iterator)
# --> 588 batch_outputs = self.predict_function(data)
#     589 outputs = append_to_outputs(batch_outputs, outputs)
#     590 callbacks.on_predict_batch_end(
#     591     end_step, {"outputs": batch_outputs}
#     592 )
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:282, in TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed(data)
#     279 @tf.autograph.experimental.do_not_convert
#     280 def one_step_on_data_distributed(data):
#     281     data = data[0]
# --> 282     outputs = self.distribute_strategy.run(
#     283         one_step_on_data, args=(data,)
#     284     )
#     285     outputs = reduce_per_replica(
#     286         outputs,
#     287         self.distribute_strategy,
#     288         reduction="concat",
#     289     )
#     290     return outputs
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:125, in TensorFlowTrainer._autoconvert_optionals.<locals>.wrapper(data)
#     117 @functools.wraps(step_func)
#     118 def wrapper(data):
#     119     converted_data = tree.map_structure(
#     120         lambda i: (
#     121             None if isinstance(i, tf.experimental.Optional) else i
#     122         ),
#     123         data,
#     124     )
# --> 125     result = step_func(converted_data)
#     126     return result
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:271, in TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data(data)
#     268 @tf.autograph.experimental.do_not_convert
#     269 def one_step_on_data(data):
#     270     """Runs a predict test step on a batch of data."""
# --> 271     return self.predict_step(data)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:110, in TensorFlowTrainer.predict_step(self, data)
#     108 x, _, _ = data_adapter_utils.unpack_x_y_sample_weight(data)
#     109 if self._call_has_training_arg:
# --> 110     y_pred = self(x, training=False)
#     111 else:
#     112     y_pred = self(x)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\layers\layer.py:953, in Layer.__call__(self, *args, **kwargs)
#     951         outputs = super().__call__(*args, **kwargs)
#     952 else:
# --> 953     outputs = super().__call__(*args, **kwargs)
#     954 # Change the layout for the layer output if needed.
#     955 # This is useful for relayout intermediate tensor in the model
#     956 # to achieve the optimal performance.
#     957 distribution = distribution_lib.distribution()
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\ops\operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\models\functional.py:183, in Functional.call(self, inputs, training, mask, **kwargs)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs,
#     185     operation_fn=lambda op: operation_fn(
#     186         op, training=training, **kwargs
#     187     ),
#     188 )
#     189 return unpack_singleton(outputs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\ops\function.py:206, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     204     operation = self._get_operation_for_node(node)
#     205     op = operation_fn(operation)
# --> 206     outputs = op(*args, **kwargs)
#     208 # Update tensor_dict.
#     209 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\models\functional.py:647, in operation_fn.<locals>.call(*args, **kwargs)
#     641     if (
#     642         name in getattr(operation, "_call_context_args", {})
#     643         and value is not None
#     644     ):
#     645         kwargs[name] = value
# --> 647 return operation(*args, **kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\layers\layer.py:953, in Layer.__call__(self, *args, **kwargs)
#     951         outputs = super().__call__(*args, **kwargs)
#     952 else:
# --> 953     outputs = super().__call__(*args, **kwargs)
#     954 # Change the layout for the layer output if needed.
#     955 # This is useful for relayout intermediate tensor in the model
#     956 # to achieve the optimal performance.
#     957 distribution = distribution_lib.distribution()
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\ops\operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:277, in BatchNormalization.call(self, inputs, training, mask)
#     274 else:
#     275     beta = None
# --> 277 outputs = ops.batch_normalization(
#     278     x=inputs,
#     279     mean=mean,
#     280     variance=variance,
#     281     axis=self.axis,
#     282     offset=beta,
#     283     scale=gamma,
#     284     epsilon=self.epsilon,
#     285 )
#     286 return ops.cast(outputs, self.compute_dtype)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\ops\nn.py:2443, in batch_normalization(x, mean, variance, axis, offset, scale, epsilon)
#    2438 if any_symbolic_tensors((x, mean, variance, offset, scale)):
#    2439     return BatchNorm(axis, epsilon).symbolic_call(
#    2440         x, mean, variance, offset, scale
#    2441     )
# -> 2443 return backend.nn.batch_normalization(
#    2444     x, mean, variance, axis, offset, scale, epsilon
#    2445 )
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\keras\src\backend\tensorflow\nn.py:1370, in batch_normalization(x, mean, variance, axis, offset, scale, epsilon)
#    1368 shape[axis] = mean.shape[0]
#    1369 mean = tf.reshape(mean, shape)
# -> 1370 variance = tf.reshape(variance, shape)
#    1371 if offset is not None:
#    1372     offset = tf.reshape(offset, shape)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\util\dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\ops\array_ops.py:199, in reshape(tensor, shape, name)
#      63 @tf_export("reshape", v1=["reshape", "manip.reshape"])
#      64 @dispatch.add_dispatch_support
#      65 def reshape(tensor, shape, name=None):  # pylint: disable=redefined-outer-name
#      66   r"""Reshapes a tensor.
#      67
#      68   Given `tensor`, this operation returns a new `tf.Tensor` that has the same
#    (...)    197     A `Tensor`. Has the same type as `tensor`.
#     198   """
# --> 199   result = gen_array_ops.reshape(tensor, shape, name)
#     200   shape_util.maybe_set_static_shape(result, shape)
#     201   return result
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py:8800, in reshape(tensor, shape, name)
#    8798     pass  # Add nodes to the TensorFlow graph.
#    8799 # Add nodes to the TensorFlow graph.
# -> 8800 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    8801       "Reshape", tensor=tensor, shape=shape, name=name)
#    8802 _result = _outputs[:]
#    8803 if _execute.must_record_gradient():
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\op_def_library.py:531, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     529 inferred = None
#     530 try:
# --> 531   inferred = ops.convert_to_tensor(
#     532       values, name=input_arg.name, as_ref=input_arg.is_ref)
#     533 except TypeError as err:
#     534   # When converting a python object such as a list of Dimensions, we
#     535   # need a dtype to be specified, thus tensor conversion may throw
#     536   # an exception which we will ignore and try again below.
#     537   pass
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:757, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     755 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     756 preferred_dtype = preferred_dtype or dtype_hint
# --> 757 return tensor_conversion_registry.convert(
#     758     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     759 )
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)    230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)    274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:291, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:289, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:614, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     612   inp = self.capture(inp)
#     613   captured_inputs.append(inp)
# --> 614 return super()._create_op_internal(  # pylint: disable=protected-access
#     615     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     616     compute_device)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:2726, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2723 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2724 # Session.run call cannot occur between creating and mutating the op.
#    2725 with self._mutation_lock():
# -> 2726   ret = Operation.from_node_def(
#    2727       node_def,
#    2728       self,
#    2729       inputs=inputs,
#    2730       output_types=dtypes,
#    2731       control_inputs=control_inputs,
#    2732       input_types=input_types,
#    2733       original_op=self._default_original_op,
#    2734       op_def=op_def,
#    2735   )
#    2736   self._create_op_helper(ret, compute_device=compute_device)
#    2737 return ret
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:1221, in Operation.from_node_def(***failed resolving arguments***)
#    1218     control_input_ops.append(control_op)
#    1220 # Initialize c_op from node_def and other inputs
# -> 1221 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1222 self = Operation(c_op, SymbolicTensor)
#    1223 self._init(g)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\XPS\Desktop\School\ComputerVision\code\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:1078, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1074   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1075                                          serialized)
#    1077 try:
# -> 1078   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1079 except errors.InvalidArgumentError as e:
#    1080   # Convert to ValueError for backwards compatibility.
#    1081   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Tải và xử lý hình ảnh đã biết
# - Hình ảnh đã biết được tải và chuyển đổi sang định dạng RGB.
# - Khuôn mặt trong hình ảnh được phát hiện, cắt và truyền vào hàm `get_embedding` để tạo embedding.
#
# Embedding này sẽ được sử dụng làm tham chiếu để so sánh độ tương đồng.

# %%
cap = cv2.VideoCapture(0)

THRESHOLD = 0.7  # ngưỡng similarity

while True:
    ret, frame = cap.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    try:
        faces = detector.detect_faces(rgb_frame)
    except Exception as e:
        print("Lỗi detect, bỏ qua frame này...")
        continue

    for face in faces:
        x, y, w, h = face['box']
        face_img = rgb_frame[y:y+h, x:x+w]

        try:
            emb = get_embedding(face_img)

            similarity = 1 - cosine(known_embedding, emb)

            if similarity > THRESHOLD:
                label = "Matched"
                color = (0, 255, 0)
            else:
                label = "Unknown"
                color = (0, 0, 255)

            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
            cv2.putText(
                frame,
                f"{label} {similarity:.2f}",
                (x, y-10),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.8,
                color,
                2
            )

        except Exception as e:
            pass

    cv2.imshow("Face Recognition - FaceNet", frame)
    # Kiểm tra nếu cửa sổ bị đóng
    if cv2.getWindowProperty("Face Recognition - FaceNet", cv2.WND_PROP_VISIBLE) < 1:
        print("Cửa sổ bị đóng, thoát chương trình...")
        break


    if cv2.waitKey(1) & 0xFF == 27:  # ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Lỗi detect, bỏ qua frame này...
# Lỗi detect, bỏ qua frame này...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step

# %% [markdown]
# ## Vòng lặp nhận diện khuôn mặt thời gian thực
# - Quay video từ webcam.
# - Phát hiện khuôn mặt trong từng khung hình và tạo embedding cho chúng.
# - So sánh embedding với embedding đã biết để tính toán độ tương đồng.
# - Hiển thị khung và nhãn ("Matched" hoặc "Unknown") xung quanh các khuôn mặt được phát hiện dựa trên ngưỡng độ tương đồng.
#
# Nhấn `ESC` để thoát vòng lặp.
